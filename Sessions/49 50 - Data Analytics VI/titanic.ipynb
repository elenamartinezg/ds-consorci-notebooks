# %%
import pandas as pd
data = pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
def sqrt_transfom_clean_(x):
    if np.isfinite(x) and x>=0:
        return np.sqrt(x)
    else:
        return np.NAN

# %%
data.Ticket.value_counts()
# Out:
# Ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# PC 17590            1
# 17463               1
# 330877              1
# 373450              1
# STON/O2. 3101282    1
# Name: count, Length: 681, dtype: int64

# %%
data[data.Ticket == '347082']
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
#
#      Parch  Ticket    Fare Cabin Embarked
# ...

# %%
cols_num = data.select_dtypes(include='number').columns
cols_num
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for col in ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']:
    sns.boxplot(data=data[col], orient='h')
    plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns
sns.boxplot(data=data, x='Pclass', y='Fare', hue='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
import seaborn as sns
fig, axs = plt.subplots(2,1, figsize=(10, 8))
axs = axs.flatten()
sns.boxplot(data=data, x='Fare', ax=axs[0], color='darkgreen')
sns.histplot(data=data, x='Fare', bins=30, kde=True, ax=axs[1], color='darkgreen')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
import seaborn as sns
fig, axs = plt.subplots(2,1, figsize=(10, 8))
axs = axs.flatten()
sns.boxplot(data=data[data['Fare'] < 200], x='Fare', ax=axs[0], color='darkgreen')
sns.histplot(data=data[data['Fare'] < 200], x='Fare', bins=30, kde=True, ax=axs[1], color='darkgreen')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
import numpy as np
sns.histplot(data=data[data.Fare > np.percentile(data.Fare, 97.7)], x='Fare', kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
import numpy as np
sns.histplot(data=data[data.Fare <= np.percentile(data.Fare, 97.7)], x='Fare', kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.jointplot(data=data, x= "Fare", y="Pclass", hue="Pclass")

# %%
data[['Fare']].describe([.05,.25,.5,.75,.9,.95, .977])
# Out:
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 5%       7.225000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# 90%     77.958300
# 95%    112.079150
# 97.7%  164.866700
# max    512.329200

# %%
import seaborn as sns
sns.boxplot(data=data, x='SibSp', y='Age', hue='SibSp')
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
import seaborn as sns
sns.boxplot(data=data, x='Parch', y='Age', hue='Parch', palette='tab10')
# Out:
# <Axes: xlabel='Parch', ylabel='Age'>

# %%
# data.dropna(inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(columns='Name')
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.Sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# data['Sex'] = data['Sex'].replace({'male': 0, 'female': 1})
# data.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Matriz de correlación para ver las relaciones entre variables
correlation_matrix = data.drop(columns=['Sex','Name','Ticket','Cabin','Embarked']).corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', square=True, cmap='viridis')
plt.title('Correlation Matrix')
plt.show()

# %%
data[data['Cabin'].isnull()]['Pclass'].value_counts(normalize=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Pclass'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Analizar los distintos campos categóricos. Definir tratamientos a realizar:
# - Corrección de categorías: value_counts? gráficas?
# - Hay algún campo que deba eliminarse por cantidad de nulos? Se podría hacer algo para evitarlo?
# - Hay algún campo que deba eliminarse ya que no aporta información?
